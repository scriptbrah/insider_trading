# %% [markdown]
# <h1>Insider Trading Python Framework</h1>
# <p>The theory is that you can predict movements in stock price based on insider sentiment. These seems to be supported by several papers, which are included in the repo.</p>

# %% [markdown]
# <h2>Interacting with the database</h2>
# <p>Here are a few commands that should help when you need to interface with the database.<br>
# * Open the insider_trading database - psql insider_trading<br>
# * List all tables - \dt<br>
# * Delete everything from insides table - TRUNCATE * FROM insiders;<br><br>
#
# Note that the database must be set up such that it will cause a conflict on reingestion of data that has already been consumed.
# </p>

# %% [markdown]
# <h2>Global Variables</h2>
# <p>These will be important to the entire script</p>

# %%
import yaml

def loadyaml(filename):
    with open(filename, "r") as yamlfile:
        try:
            return yaml.safe_load(yamlfile)
        except yaml.YAMLErorr as err:
            print(err)   

stocks = loadyaml("snp500.yaml")
settings = loadyaml("settings.yaml")

print("Stocks struct looks like: " + str(stocks))
print("Settings struct looks like: " + str(settings))
# Out:
# Stocks struct looks like: {'A': {'CIK': 1090872, 'Name': 'Agilent Technologies', 'Sector': 'Health Care', 'Symbol': 'A', 'Watch': False}, 'AAL': {'CIK': 6201, 'Name': 'American Airlines Group', 'Sector': 'Industrials', 'Symbol': 'AAL', 'Watch': False}, 'AAP': {'CIK': 1158449, 'Name': 'Advance Auto Parts', 'Sector': 'Consumer Discretionary', 'Symbol': 'AAP', 'Watch': False}, 'AAPL': {'CIK': 320193, 'Name': 'Apple', 'Sector': 'Information Technology', 'Symbol': 'AAPL', 'Watch': False}, 'ABBV': {'CIK': 1551152, 'Name': 'AbbVie', 'Sector': 'Health Care', 'Symbol': 'ABBV', 'Watch': False}, 'ABC': {'CIK': 1140859, 'Name': 'AmerisourceBergen', 'Sector': 'Health Care', 'Symbol': 'ABC', 'Watch': False}, 'ABMD': {'CIK': 815094, 'Name': 'Abiomed', 'Sector': 'Health Care', 'Symbol': 'ABMD', 'Watch': False}, 'ABT': {'CIK': 1800, 'Name': 'Abbott Laboratories', 'Sector': 'Health Care', 'Symbol': 'ABT', 'Watch': False}, 'ACN': {'CIK': 1467373, 'Name': 'Accenture', 'Sector': 'Information Technology', 'Symbol': 'ACN', 'Watch': False}, 'ADBE': {'CIK': 796343, 'Name': 'Adobe', 'Sector': 'Information Technology', 'Symbol': 'ADBE', 'Watch': False}, 'ADI': {'CIK': 6281, 'Name': 'Analog Devices', 'Sector': 'Information Technology', 'Symbol': 'ADI', 'Watch': False}, 'ADM': {'CIK': 7084, 'Name': 'ADM', 'Sector': 'Consumer Staples', 'Symbol': 'ADM', 'Watch': False}, 'ADP': {'CIK': 8670, 'Name': 'Automatic Data Processing', 'Sector': 'Information Technology', 'Symbol': 'ADP', 'Watch': False}, 'ADSK': {'CIK': 769397, 'Name': 'Autodesk', 'Sector': 'Information Technology', 'Symbol': 'ADSK', 'Watch': False}, 'AEE': {'CIK': 1002910, 'Name': 'Ameren Corp', 'Sector': 'Utilities', 'Symbol': 'AEE', 'Watch': False}, 'AEP': {'CIK': 4904, 'Name': 'American Electric Power', 'Sector': 'Utilities', 'Symbol': 'AEP', 'Watch': False}, 'AES': {'CIK': 874761, 'Name': 'AES Corp', 'Sector': 'Utilities', 'Symbol': 'AES', 'Watch': False}, 'AFL': {'CIK': 4977, 'Name': 'Aflac', 'Sector': 'Financials', 'Symbol': 'AFL', 'Watch': False}, 'AIG': {'CIK': 5272, 'Name': 'American International Group', 'Sector': 'Financials', 'Symbol': 'AIG', 'Watch': False}, 'AIZ': {'CIK': 1267238, 'Name': 'Assurant', 'Sector': 'Financials', 'Symbol': 'AIZ', 'Watch': False}, 'AJG': {'CIK': 354190, 'Name': 'Arthur J. Gallagher & Co.', 'Sector': 'Financials', 'Symbol': 'AJG', 'Watch': False}, 'AKAM': {'CIK': 1086222, 'Name': 'Akamai Technologies', 'Sector': 'Information Technology', 'Symbol': 'AKAM', 'Watch': False}, 'ALB': {'CIK': 915913, 'Name': 'Albemarle Corporation', 'Sector': 'Materials', 'Symbol': 'ALB', 'Watch': False}, 'ALGN': {'CIK': 1097149, 'Name': 'Align Technology', 'Sector': 'Health Care', 'Symbol': 'ALGN', 'Watch': False}, 'ALK': {'CIK': 766421, 'Name': 'Alaska Air Group', 'Sector': 'Industrials', 'Symbol': 'ALK', 'Watch': False}, 'ALL': {'CIK': 899051, 'Name': 'Allstate Corp', 'Sector': 'Financials', 'Symbol': 'ALL', 'Watch': False}, 'ALLE': {'CIK': 1579241, 'Name': 'Allegion', 'Sector': 'Industrials', 'Symbol': 'ALLE', 'Watch': False}, 'AMAT': {'CIK': 6951, 'Name': 'Applied Materials', 'Sector': 'Information Technology', 'Symbol': 'AMAT', 'Watch': False}, 'AMCR': {'CIK': 1748790, 'Name': 'Amcor', 'Sector': 'Materials', 'Symbol': 'AMCR', 'Watch': False}, 'AMD': {'CIK': 2488, 'Name': 'Advanced Micro Devices', 'Sector': 'Information Technology', 'Symbol': 'AMD', 'Watch': False}, 'AME': {'CIK': 1037868, 'Name': 'Ametek', 'Sector': 'Industrials', 'Symbol': 'AME', 'Watch': False}, 'AMGN': {'CIK': 318154, 'Name': 'Amgen', 'Sector': 'Health Care', 'Symbol': 'AMGN', 'Watch': False}, 'AMP': {'CIK': 820027, 'Name': 'Ameriprise Financial', 'Sector': 'Financials', 'Symbol': 'AMP', 'Watch': False}, 'AMT': {'CIK': 1053507, 'Name': 'American Tower', 'Sector': 'Real Estate', 'Symbol': 'AMT', 'Watch': False}, 'AMZN': {'CIK': 1018724, 'Name': 'Amazon', 'Sector': 'Consumer Discretionary', 'Symbol': 'AMZN', 'Watch': False}, 'ANET': {'CIK': 1596532, 'Name': 'Arista Networks', 'Sector': 'Information Technolog ...
# Settings struct looks like: {'interval': 1, 'start date': datetime.date(2010, 1, 1), 'sectors': ['Industrials', 'Health Care', 'Information Technology', 'Communication Services', 'Consumer Staples', 'Consumer Discretionary', 'Utilities', 'Financials', 'Materials', 'Real Estate', 'Energy']}

# %% [markdown]
# <h2>Webscraping</h2>
# <p>This section will load insider trading statistics into the insider_trading database table insiders. We will also collect trading volume and stock price information in this section.</p>

# %%
from tqdm import tqdm
import os
import requests
from bs4 import BeautifulSoup
import psycopg        
            
def fetch_insider_trading(stocks, end_date, connection):
    
    def to_soup(url):
        url_response = requests.get(url)
        webpage = url_response.content
        soup = BeautifulSoup(webpage, 'html.parser')
        return soup

    def append_insider_data(single_insider, connection, company):
        try:
            cursor = connection.cursor()
            postgres_insert_query = """INSERT INTO insiders (
                                            acquistion_or_disposition, 
                                            transaction_date, 
                                            deemed_execution_date, 
                                            reporting_owner, form, 
                                            transaction_type, 
                                            direct_or_indirect_ownership, 
                                            number_of_securities_transacted, 
                                            number_of_securities_owned, 
                                            line_number, 
                                            owner_cik, 
                                            security_name, 
                                            company) 
                                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                                        ON CONFLICT DO NOTHING"""
            record_to_insert = (single_insider[0],
                                single_insider[1],
                                single_insider[2],
                                single_insider[3],
                                single_insider[4],
                                single_insider[5],
                                single_insider[6],
                                single_insider[7],
                                single_insider[8],
                                single_insider[9],
                                single_insider[10],
                                single_insider[11],
                                company)
            cursor.execute(postgres_insert_query, record_to_insert)
            connection.commit()
            cursor.close()
        except Exception as e:
            print(e)
    
    # TODO: Need to insert if statement for whether watch is marked true.
    with tqdm(total = len(stocks)) as progress_bar:
        for stock in stocks:
            if stocks[stock].get("Watch") == True:
                try:
                    page = 0
                    urls = ['https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK='+str(stocks[stock].get("CIK"))+'&type=&dateb=&owner=include&start='+str(page*80)]
                    for url in urls:
                        print("fetching data from " + url)
                        soup = to_soup(url)
                        transaction_report = soup.find('table', {'id':'transaction-report'})

                        t_chil = [i for i in transaction_report.children]
                        t_cont = [i for i in t_chil if i != '\n']

                        data_rough = [i for lst in t_cont[1:] for i in lst.get_text().split('\n') if i != '' ]
                        data = [data_rough[i:i+12] for i in range(0,len(data_rough), 12)]
                        last_line = data[-1]
                        for row in data:
                            if (end_date > row[1]):
                                break
                            else:
                                if (row != last_line):
                                    append_insider_data(row, connection, stocks[stock].get("Symbol"))
                                else:
                                    page += 1
                                    urls.append('https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK='+str(stocks[stock].get("CIK"))+'&type=&dateb=&owner=include&start='+str(page*80))
                    os.system('cls' if os.name=='nt' else 'clear')
                    progress_bar.update(1)
                except:
                    print("failed to find " + stocks[stock].get("Name") + " resource")
                    os.system('cls' if os.name=='nt' else 'clear')
                    progress_bar.update(1)
            else:
                progress_bar.update(1)
    connection.close()
            
if __name__ == "__main__":
    connection = psycopg.connect(user="ethan", password="ethan", host="127.0.0.1", port="5432", dbname="insider_trading")
    
    fetch_insider_trading(stocks, str(settings.get("start date")), connection)
# Out:
#   0%|                                                                                                                                                                 | 0/501 [00:00<?, ?it/s]
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=0
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=80
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=160
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=240
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=320
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=400
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=480
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=560
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=640
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=720
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=800
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=880
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=960
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1040
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1120
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1200
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1280
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1360
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1440
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1520
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1600
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1680
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1760
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1840
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=1920
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=2000
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=857005&type=&dateb=&owner=include&start=2080
#  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                    | 380/501 [00:23<00:07, 16.33it/s]
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=0
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=80
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=160
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=240
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=320
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=400
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=480
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=560
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=640
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=720
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=800
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=880
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=960
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1040
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1120
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1200
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1280
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1360
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1440
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1520
#  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                    | 380/501 [00:41<00:07, 16.33it/s]
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1600
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1680
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=78239&type=&dateb=&owner=include&start=1760
#  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                    | 381/501 [00:46<00:17,  6.74it/s]
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=0
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=80
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=160
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=240
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=320
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=400
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=480
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=560
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=640
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=720
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=800
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=880
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=960
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1040
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1120
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1200
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1280
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1360
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1440
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1520
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1600
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1680
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1760
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1840
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=1920
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2000
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2080
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2160
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2240
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2320
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2400
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=97210&type=&dateb=&owner=include&start=2480
#  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                     | 431/501 [01:17<00:17,  4.06it/s]
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=0
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=80
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=160
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=240
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=320
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=400
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=480
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=560
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=640
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=720
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=800
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=880
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=960
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1040
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1120
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1200
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1280
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1360
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1440
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1520
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1600
# fetching data from https://www.sec.gov/cgi-bin/own-disp?action=getissuer&CIK=109198&type=&dateb=&owner=include&start=1680
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 501/501 [01:38<00:00,  5.09it/s]

# %% [markdown]
# <h2>Analysis</h2>
# <p>We're going to define a set of functions here that help us correlate changes in stock price with insider trading order volume.</p>

# %%
import pandas_datareader as web
import datetime
from matplotlib import pyplot as plt
import pandas as pd
import psycopg
import warnings

def load_rel_data(startDate, endDate, stockSymbol):
    # Get insider trading info from the database.
    warnings.filterwarnings("ignore")
    with psycopg.connect("host='{}' port={} dbname='{}' user={} password={}"
                         .format("127.0.0.1", "5432", "insider_trading", "ethan", "ethan")) as conn:
        sql_D = "SELECT transaction_date, number_of_securities_transacted FROM insiders WHERE company = '{}' AND acquistion_or_disposition = 'D' AND security_name like 'Common Stock%' AND direct_or_indirect_ownership = '--D' AND transaction_type like 'S-%';".format(stockSymbol)
        sql_A = "SELECT transaction_date, number_of_securities_transacted FROM insiders WHERE company = '{}' AND acquistion_or_disposition = 'A' AND security_name like 'Common Stock%' AND direct_or_indirect_ownership = '--D' AND transaction_type like 'P-%';".format(stockSymbol)
        
        dat_D = pd.read_sql_query(sql_D, conn)
        dat_A = pd.read_sql_query(sql_A, conn)
        
    # Change types to datetime and float to make the graphs work.
    dat_D['transaction_date'] = pd.to_datetime(dat_D['transaction_date'], format='%Y-%m-%d')
    dat_D = dat_D.astype({'number_of_securities_transacted':'float'})
    
    dat_A['transaction_date'] = pd.to_datetime(dat_A['transaction_date'], format='%Y-%m-%d')
    dat_A = dat_A.astype({'number_of_securities_transacted':'float'})

    # Sum everything that has the same transaction date. 
    # It may be the case that you have two large sell orders from different insiders.
    dat_D = dat_D.groupby('transaction_date').sum()
    dat_A = dat_A.groupby('transaction_date').sum()
    
    # Rename columns before zipping together.
    dat_D = dat_D.rename(columns={'number_of_securities_transacted': 'VolumeSold'})
    dat_A = dat_A.rename(columns={'number_of_securities_transacted': 'VolumeBought'})

    # Read from the web.
    df = web.DataReader(stockSymbol, 'yahoo', startDate, endDate)

    # Trim the stuff we don't care about.
    trimmed = df.drop(df.columns[[0,1,2,3]], axis=1)

    # Zip together volume, insider-sold securities, and close price of a stock.
    concatdat = pd.concat([trimmed, dat_D, dat_A], axis=1)
    
    # Rename the columns of the dataframe so they can be called easier.
    concatdat = concatdat.rename(columns={'Adj Close': 'ClosePrice'})
    
    # Set and rename the index.
    concatdat.index.names = ["Date"]
    concatdat = concatdat.reset_index()
    
    # Trim the dataset to the specified size.
    mask = (concatdat["Date"] > startDate) & (concatdat["Date"] <= endDate)
    concatdat = concatdat.loc[mask]
    
    return concatdat

def graph_sold_price(concatdat):
    # Create a figure object that we can store three plots in.
    fig,volume = plt.subplots(figsize=(15,6))
    
    # Volume sold will be shown as red, volume bought will be sold as green.
    volume.bar(concatdat.Date, concatdat.VolumeSold*-1, color="red", width=3)
    volume.bar(concatdat.Date, concatdat.VolumeBought, color="green", width=4)
    
    # Set axis label info.
    volume.set_xlabel("Date", fontsize = 14)
    volume.set_ylabel("Volume Bought (GREEN) or Sold (RED)", color="yellow", fontsize=14)
    
    # Create a black line to draw sharp distinction between sold and bought volume.
    volume.axhline(y=0, color= 'black', linewidth=1,)
    
    # Use twinx() to add another plot with a different y-axis.
    price=volume.twinx()
    price.plot(concatdat.Date, concatdat.ClosePrice, color="grey")
    price.set_ylabel("Price at Close", color="grey", fontsize=14)
    
    # Display the plot.
    plt.show()

if __name__ == "__main__":
    # Define the region of time over which you are interested.
    start = datetime.datetime(2010, 1, 1)
    end = datetime.datetime(2022, 10, 29)
    
    # Iterate over all stock listed in sandp10.yaml.
    for stock in stocks:
        if stocks[stock].get("Watch") == True:
            print("Displaying data for " + stocks[stock].get("Symbol") + " over specified time period.")
            data = load_rel_data(start, end, stocks[stock].get("Symbol"))
            graph_sold_price(data)
# Out:
# Displaying data for PTC over specified time period.
# Displaying data for PVH over specified time period.
# Displaying data for TER over specified time period.
# Displaying data for TJX over specified time period.
